# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io

# load .mat file
mat = scipy.io.loadmat('../dataset/AR1a_W.mat')

# get the data
data = mat['csi_buff']

# plot the data
# plt.plot(data)

# # show the plot

# plt.show()

# print the data to csv file only first 10 rows 
data = data[:1]
np.savetxt('csi_buff.csv', data, delimiter=',')

print(data)
# Out:
# [[-1.100e+02 +27.j -1.100e+01 +12.j  1.545e+03-131.j  1.545e+03 -74.j
#    1.524e+03 -15.j  1.487e+03 +38.j  1.416e+03+104.j  1.345e+03+179.j
#    1.270e+03+257.j  1.173e+03+323.j  1.072e+03+385.j  9.390e+02+449.j
#    8.130e+02+504.j  6.780e+02+555.j  5.410e+02+607.j  4.120e+02+655.j
#    2.850e+02+693.j  1.680e+02+721.j  4.900e+01+750.j -5.900e+01+766.j
#   -1.490e+02+775.j -2.220e+02+767.j -2.830e+02+761.j -3.240e+02+743.j
#   -3.580e+02+709.j -3.750e+02+676.j -3.690e+02+637.j -3.430e+02+594.j
#   -2.890e+02+541.j -2.330e+02+483.j -1.650e+02+427.j -8.300e+01+364.j
#    3.000e+00+297.j  9.700e+01+230.j  1.890e+02+158.j  2.810e+02 +88.j
#    3.760e+02 +23.j  4.620e+02 -32.j  5.350e+02 -88.j  6.000e+02-135.j
#    6.430e+02-176.j  6.740e+02-207.j  6.830e+02-230.j  6.890e+02-241.j
#    6.810e+02-228.j  6.550e+02-216.j  6.130e+02-187.j  5.500e+02-146.j
#    4.800e+02 -95.j  4.010e+02 -32.j  3.100e+02 +27.j  2.200e+02+100.j
# ...
